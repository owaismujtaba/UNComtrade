# %%
import os

# %%
with open('a.txt', 'w') as file:
    for i in range(900000, 1000000):
        file.write(f"{i},")

# %%
numbers = list(range(10000, 1000000))

# %%
with open('/home/owais/UNComtrade/data/HS6Digit/6DigitHSCode2007.txt', 'r') as file:
    content = file.read()
    hs_codes = content.split(',')

# %%
len(hs_codes)
# Out:
# 786366

# %%
validate_codes = []
for code in numbers:
    if str(code) not in hs_codes:
        validate_codes.append(code)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       2 for code in numbers:
#       3     if str(code) not in hs_codes:
# ----> 4         validate_codes.append(code)
#
# KeyboardInterrupt:

# %%
hs_codes = [int(code) for code in hs_codes]
hs_codes.sort()

valid = set(numbers) - set(hs_codes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 hs_codes = [int(code) for code in hs_codes]
#       2 hs_codes.sort()
#       4 valid = set(numbers) - set(hs_codes)
#
# Cell In[16], line 1, in <listcomp>(.0)
# ----> 1 hs_codes = [int(code) for code in hs_codes]
#       2 hs_codes.sort()
#       4 valid = set(numbers) - set(hs_codes)
#
# ValueError: invalid literal for int() with base 10: ''
